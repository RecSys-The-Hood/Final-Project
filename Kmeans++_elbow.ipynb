# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
df=pd.read_csv("./Final_Combined_Dataset.csv")
df=df.set_index(keys="zpid")
df
# Out:
#             bedrooms  bathrooms    price  zipcode  \
# zpid
# 100650           3.0        2.0   122400    35172
# 394191           2.0        2.0  1475000    20037
# 394956           2.0        3.0  1200000    20037
# 395184           0.0        1.0   255000    20037
# 395274           0.0        1.0   285000    20037
# ...              ...        ...      ...      ...
# 2140770427       2.0        2.0   236800    94089
# 2141107496      10.0        4.0   395000    60609
# 2144732235       2.0        2.0  1650000     2116
# 2146966820       2.0        2.0  2950000    94114
# 2146972089       2.0        1.0   159000    60004
#
#                                                        hdpUrl   cityId  \
# zpid
# 100650      /homedetails/513-Hagwood-Cir-Trafford-AL-35172...      NaN
# 394191      /homedetails/2555-Pennsylvania-Ave-NW-APT-501-...  41568.0
# 394956      /homedetails/800-25th-St-NW-1001-Washington-DC...  41568.0
# 395184      /homedetails/922-24th-St-NW-APT-309-Washington...  41568.0
# 395274      /homedetails/922-24th-St-NW-APT-820-Washington...  41568.0
# ...                                                       ...      ...
# 2140770427  /homedetails/1111-Morse-Ave-SPC-101-Sunnyvale-...  54626.0
# 2141107496  /homedetails/1822-W-46th-St-Chicago-IL-60609/2...  17426.0
# 2144732235  /homedetails/221-Columbus-Ave-APT-603-Boston-M...  44269.0
# 2146966820  /homedetails/760-Church-St-3-San-Francisco-CA-...  20330.0
# 2146972089  /homedetails/4214-Bonhill-Dr-APT-3F-Arlington-...  50764.0
#
#                  homeType  livingArea  livingAreaValue  rentZestimate  ...  \
# zpid                                                                   ...
# 100650      SINGLE_FAMILY      1400.0           1400.0         1200.0  ...
# 394191              CONDO      1590.0           1590.0            NaN  ...
# 394956              CONDO      2007.0           2007.0         6999.0  ...
# 395184          APARTMENT       498.0            498.0         1892.0  ...
# 395274              CONDO       465.0            465.0         1914.0  ...
# ...                   ...         ...              ...            ...  ...
# 2140770427   MANUFACTURED      1440.0           1440.0          464.0  ...
# 2141107496   MULTI_FAMILY         NaN              NaN            NaN  ...
# 2144732235          CONDO      1508.0           1508.0         5726.0  ...
# 2146966820          CONDO      1622.0           1622.0         5068.0  ...
# 2146972089          CONDO       900.0            900.0         1450.0  ...
#
#                                                originalPhotos  \
# zpid
# 100650      ['https://photos.zillowstatic.com/fp/933bbfddb...
# 394191      ['https://photos.zillowstatic.com/fp/7728b70d7...
# 394956      ['https://photos.zillowstatic.com/fp/947993164...
# 395184      ['https://photos.zillowstatic.com/fp/0a2f90e81...
# 395274      ['https://photos.zillowstatic.com/fp/dcf342b52...
# ...                                                       ...
# 2140770427  ['https://photos.zillowstatic.com/fp/5577a7caa...
# 2141107496  ['https://photos.zillowstatic.com/fp/91d4eff7c...
# 2144732235  ['https://photos.zillowstatic.com/fp/9d1560a0d...
# 2146966820  ['https://photos.zillowstatic.com/fp/c9a9f7e88...
# 2146972089  ['https://photos.zillowstatic.com/fp/83e68a72f...
#
#                        address.streetAddress       address.city address.state  \
# zpid
# 100650                       513 Hagwood Cir           Trafford            AL
# 394191      2555 Pennsylvania Ave NW APT 501         Washington            DC
# 394956                  800 25th St NW #1001         Washington            DC
# 395184                922 24th St NW APT 309         Washington            DC
# 395274                922 24th St NW APT 820         Washington            DC
# ...                                      ...                ...           ...
# 2140770427            1111 Morse Ave SPC 101          Sunnyvale            CA
# 2141107496                    1822 W 46th St            Chicago            IL
# 2144732235          221 Columbus Ave APT 603             Boston            MA
# 2146966820                  760 Church St #3      San Francisco            CA
# 2146972089            4214 Bonhill Dr APT 3F  Arlington Heights            IL
#
#            address.zipcode                                     image_captions  \
# zpid
# 100650               35172  a photograph of a house in the woods with a po...
# 394191               20037  a photograph of a large building with a lot of...
# 394956               20037  a photograph of a building with cars parked in...
# 395184               20037  a photograph of a large building with a lot of...
# 395274               20037  a photograph of a bedroom with a bed, couch, a...
# ...                    ...                                                ...
# 2140770427           94089  a photograph of a mobile home with a flag on t...
# 2141107496           60609  a photograph of a two story brick building wit...
# 2144732235            2116  a photograph of a building with a large entran...
# 2146966820           94114  a photograph of a rooftop deck with a view of ...
# 2146972089           60004  a photograph of a building with a car parked i...
#
#            leisure_within_5km shops_within_5km schools_within_5km  \
# zpid
# 100650                      0                0                  0
# 394191                     16              167                118
# 394956                     14              161                104
# 395184                     17              168                108
# 395274                     17              168                108
# ...                       ...              ...                ...
# 2140770427                  0                0                  0
# 2141107496                  0               33                 41
# 2144732235                  0                0                  0
# 2146966820                 10              323                 68
# 2146972089                  0                0                  0
#
#            transit_within_2km
# zpid
# 100650                      0
# 394191                    159
# 394956                    150
# 395184                    168
# 395274                    170
# ...                       ...
# 2140770427                  0
# 2141107496                186
# 2144732235                  0
# 2146966820                461
# 2146972089                  0
#
# [6936 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'price', 'zipcode', 'hdpUrl', 'cityId',
#        'homeType', 'livingArea', 'livingAreaValue', 'rentZestimate',
#        'description', 'latitude', 'longitude', 'homeInsights', 'photoCount',
#        'originalPhotos', 'address.streetAddress', 'address.city',
#        'address.state', 'address.zipcode', 'image_captions',
#        'leisure_within_5km', 'shops_within_5km', 'schools_within_5km',
#        'transit_within_2km'],
#       dtype='object')

# %%
df1=df.drop(columns=['zipcode','hdpUrl','cityId','livingAreaValue','rentZestimate','photoCount','address.streetAddress','originalPhotos','latitude','longitude'])

df1
# Out:
#             bedrooms  bathrooms    price       homeType  livingArea  \
# zpid
# 100650           3.0        2.0   122400  SINGLE_FAMILY      1400.0
# 394191           2.0        2.0  1475000          CONDO      1590.0
# 394956           2.0        3.0  1200000          CONDO      2007.0
# 395184           0.0        1.0   255000      APARTMENT       498.0
# 395274           0.0        1.0   285000          CONDO       465.0
# ...              ...        ...      ...            ...         ...
# 2140770427       2.0        2.0   236800   MANUFACTURED      1440.0
# 2141107496      10.0        4.0   395000   MULTI_FAMILY         NaN
# 2144732235       2.0        2.0  1650000          CONDO      1508.0
# 2146966820       2.0        2.0  2950000          CONDO      1622.0
# 2146972089       2.0        1.0   159000          CONDO       900.0
#
#                                                   description  \
# zpid
# 100650      REO Occupied – NO ACCESS OR VIEWINGS of this p...
# 394191      OPEN SATURDAY AND SUNDAY - 1-4 ! RARELY AVAILA...
# 394956      NEW ON THE MARKET! Estate Sale being sold stri...
# 395184      Beautiful studio condominium located in the vi...
# 395274      Luxury living in the heart of Foggy Bottom. We...
# ...                                                       ...
# 2140770427  Your home awaits in this recently updated 2-be...
# 2141107496  SOLID BRICK BUILDING WITH 4 legal unit PLUS 1 ...
# 2144732235  Iconic South End architecture at the Albert A....
# 2146966820  Stunning penthouse unit in a Dolores Park Trop...
# 2146972089  Great chance to own this updated & ready to mo...
#
#                                                  homeInsights  \
# zpid
# 100650      [{'insights': [{'modelId': 'v2-2-backfill-samp...
# 394191      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 394956      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 395184      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 395274      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# ...                                                       ...
# 2140770427  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 2141107496  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 2144732235  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 2146966820  [{'insights': [{'modelId': 'v2-2-llm-correct',...
# 2146972089  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
#
#                  address.city address.state address.zipcode  \
# zpid
# 100650               Trafford            AL           35172
# 394191             Washington            DC           20037
# 394956             Washington            DC           20037
# 395184             Washington            DC           20037
# 395274             Washington            DC           20037
# ...                       ...           ...             ...
# 2140770427          Sunnyvale            CA           94089
# 2141107496            Chicago            IL           60609
# 2144732235             Boston            MA            2116
# 2146966820      San Francisco            CA           94114
# 2146972089  Arlington Heights            IL           60004
#
#                                                image_captions  \
# zpid
# 100650      a photograph of a house in the woods with a po...
# 394191      a photograph of a large building with a lot of...
# 394956      a photograph of a building with cars parked in...
# 395184      a photograph of a large building with a lot of...
# 395274      a photograph of a bedroom with a bed, couch, a...
# ...                                                       ...
# 2140770427  a photograph of a mobile home with a flag on t...
# 2141107496  a photograph of a two story brick building wit...
# 2144732235  a photograph of a building with a large entran...
# 2146966820  a photograph of a rooftop deck with a view of ...
# 2146972089  a photograph of a building with a car parked i...
#
#             leisure_within_5km  shops_within_5km  schools_within_5km  \
# zpid
# 100650                       0                 0                   0
# 394191                      16               167                 118
# 394956                      14               161                 104
# 395184                      17               168                 108
# 395274                      17               168                 108
# ...                        ...               ...                 ...
# 2140770427                   0                 0                   0
# 2141107496                   0                33                  41
# 2144732235                   0                 0                   0
# 2146966820                  10               323                  68
# 2146972089                   0                 0                   0
#
#             transit_within_2km
# zpid
# 100650                       0
# 394191                     159
# 394956                     150
# 395184                     168
# 395274                     170
# ...                        ...
# 2140770427                   0
# 2141107496                 186
# 2144732235                   0
# 2146966820                 461
# 2146972089                   0
#
# [6936 rows x 15 columns]

# %%
null_percentage = (df1.isnull().sum() / len(df1)) * 100
null_percentage
# Out:
# bedrooms              1.831027
# bathrooms             1.715686
# price                 0.000000
# homeType              0.000000
# livingArea            1.485006
# description           1.196655
# homeInsights          5.017301
# address.city          0.000000
# address.state         0.000000
# address.zipcode       0.000000
# image_captions        0.432526
# leisure_within_5km    0.000000
# shops_within_5km      0.000000
# schools_within_5km    0.000000
# transit_within_2km    0.000000
# dtype: float64

# %%
df1['leisure_within_5km'].median(),df1['transit_within_2km'].median(),df1['schools_within_5km'].median(),df1['transit_within_2km'].median()
# Out:
# (0.0, 0.0, 1.0, 0.0)

# %%
mode_value = df1['bedrooms'].mode()[0]
mod_1=df1['bathrooms'].mode()[0]
living_mod=df1['livingArea'].mean()
# Replace null values with the mode
df1['bedrooms']=df1['bedrooms'].fillna(mode_value)
df1['bathrooms']=df1['bathrooms'].fillna(mod_1)
df1['livingArea']=df1['livingArea'].fillna(living_mod)

columns_to_check = ['description', 'homeInsights','image_captions']

# Remove rows with all null values in specified columns
df1 = df1.dropna(subset=columns_to_check, how='all')
df1
# Out:
#             bedrooms  bathrooms    price       homeType   livingArea  \
# zpid
# 100650           3.0        2.0   122400  SINGLE_FAMILY  1400.000000
# 394191           2.0        2.0  1475000          CONDO  1590.000000
# 394956           2.0        3.0  1200000          CONDO  2007.000000
# 395184           0.0        1.0   255000      APARTMENT   498.000000
# 395274           0.0        1.0   285000          CONDO   465.000000
# ...              ...        ...      ...            ...          ...
# 2140770427       2.0        2.0   236800   MANUFACTURED  1440.000000
# 2141107496      10.0        4.0   395000   MULTI_FAMILY  1820.995024
# 2144732235       2.0        2.0  1650000          CONDO  1508.000000
# 2146966820       2.0        2.0  2950000          CONDO  1622.000000
# 2146972089       2.0        1.0   159000          CONDO   900.000000
#
#                                                   description  \
# zpid
# 100650      REO Occupied – NO ACCESS OR VIEWINGS of this p...
# 394191      OPEN SATURDAY AND SUNDAY - 1-4 ! RARELY AVAILA...
# 394956      NEW ON THE MARKET! Estate Sale being sold stri...
# 395184      Beautiful studio condominium located in the vi...
# 395274      Luxury living in the heart of Foggy Bottom. We...
# ...                                                       ...
# 2140770427  Your home awaits in this recently updated 2-be...
# 2141107496  SOLID BRICK BUILDING WITH 4 legal unit PLUS 1 ...
# 2144732235  Iconic South End architecture at the Albert A....
# 2146966820  Stunning penthouse unit in a Dolores Park Trop...
# 2146972089  Great chance to own this updated & ready to mo...
#
#                                                  homeInsights  \
# zpid
# 100650      [{'insights': [{'modelId': 'v2-2-backfill-samp...
# 394191      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 394956      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 395184      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 395274      [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# ...                                                       ...
# 2140770427  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 2141107496  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 2144732235  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
# 2146966820  [{'insights': [{'modelId': 'v2-2-llm-correct',...
# 2146972089  [{'insights': [{'modelId': 'z-nrt-pdc-tags', '...
#
#                  address.city address.state address.zipcode  \
# zpid
# 100650               Trafford            AL           35172
# 394191             Washington            DC           20037
# 394956             Washington            DC           20037
# 395184             Washington            DC           20037
# 395274             Washington            DC           20037
# ...                       ...           ...             ...
# 2140770427          Sunnyvale            CA           94089
# 2141107496            Chicago            IL           60609
# 2144732235             Boston            MA            2116
# 2146966820      San Francisco            CA           94114
# 2146972089  Arlington Heights            IL           60004
#
#                                                image_captions  \
# zpid
# 100650      a photograph of a house in the woods with a po...
# 394191      a photograph of a large building with a lot of...
# 394956      a photograph of a building with cars parked in...
# 395184      a photograph of a large building with a lot of...
# 395274      a photograph of a bedroom with a bed, couch, a...
# ...                                                       ...
# 2140770427  a photograph of a mobile home with a flag on t...
# 2141107496  a photograph of a two story brick building wit...
# 2144732235  a photograph of a building with a large entran...
# 2146966820  a photograph of a rooftop deck with a view of ...
# 2146972089  a photograph of a building with a car parked i...
#
#             leisure_within_5km  shops_within_5km  schools_within_5km  \
# zpid
# 100650                       0                 0                   0
# 394191                      16               167                 118
# 394956                      14               161                 104
# 395184                      17               168                 108
# 395274                      17               168                 108
# ...                        ...               ...                 ...
# 2140770427                   0                 0                   0
# 2141107496                   0                33                  41
# 2144732235                   0                 0                   0
# 2146966820                  10               323                  68
# 2146972089                   0                 0                   0
#
#             transit_within_2km
# zpid
# 100650                       0
# 394191                     159
# 394956                     150
# 395184                     168
# 395274                     170
# ...                        ...
# 2140770427                   0
# 2141107496                 186
# 2144732235                   0
# 2146966820                 461
# 2146972089                   0
#
# [6935 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt


label_encoder = LabelEncoder()
df1['homeType'] = label_encoder.fit_transform(df1['homeType'])
# Out:
# C:\Users\kalya\AppData\Local\Temp\ipykernel_22064\3433511660.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['homeType'] = label_encoder.fit_transform(df1['homeType'])

# %%
dfs_by_category = {}

# Get unique values in the 'Category' column
unique_categories = df1['address.state'].unique()

# Iterate over unique categories
for category in unique_categories:
    # Filter the DataFrame for the current category
    filtered_df = df1[df1['address.state'] == category]
    
    # Add the filtered DataFrame to the dictionary with category as the key
    dfs_by_category[category] = filtered_df

# Access the DataFrames using category keys
for category, df_category in dfs_by_category.items():
    print(f"Category: {category}")
    print(len(df_category))
    # print(df_category)
# Out:
# Category: AL
# 110
# Category: DC
# 497
# Category: IL
# 500
# Category: NV
# 494
# Category: Las Vegas
# 1
# Category: AZ
# 496
# Category: PA
# 497
# Category: GA
# 494
# Category: CA
# 1296
# Category: TX
# 559
# Category: NY
# 500
# Category: FL
# 500
# Category: MA
# 494
# Category: MI
# 496
# Category: ['https://photos.zillowstatic.com/fp/b721ed70b8f89663562a09d6a0bc0c0f-o_a.jpg', 'https://photos.zillowstatic.com/fp/7748fb50d89a7bf4233a5d85c16fde42-o_a.jpg', 'https://photos.zillowstatic.com/fp/ecfba145de869f95ceb6ef3caa481797-o_a.jpg', 'https://photos.zillowstatic.com/fp/b610ce04c006a420be34dc4362e99702-o_a.jpg', 'https://photos.zillowstatic.com/fp/71568e02f22bbfcdfdea6042ea5a102d-o_a.jpg', 'https://photos.zillowstatic.com/fp/e4e06bd81379cfbc3bfcd420244f9a96-o_a.jpg', 'https://photos.zillowstatic.com/fp/696adb577dc147576dae7f1a279dc453-o_a.jpg', 'https://photos.zillowstatic.com/fp/b18a2ae772d329a4e5693f88c73c9b11-o_a.jpg', 'https://photos.zillowstatic.com/fp/5ca6266575b5ae8505b12870cf26f38d-o_a.jpg', 'https://photos.zillowstatic.com/fp/f6adcb2297f810d7e1601daf131eb699-o_a.jpg', 'https://photos.zillowstatic.com/fp/4a8fa6d405674412ff9390ed68c94fee-o_a.jpg', 'https://photos.zillowstatic.com/fp/8212e88e3c5866b23bedaf4edf09be15-o_a.jpg', 'https://photos.zillowstatic.com/fp/e070702e71677616723b03b8b35c03c6-o_a.jpg', 'https://photos.zillowstatic.com/fp/dc7edc1224e28176aeb57a619bb8b086-o_a.jpg', 'https://photos.zillowstatic.com/fp/da78f1ff24076d671976906e91292881-o_a.jpg', 'https://photos.zillowstatic.com/fp/d8b66bcbfd3fe011668bc61a21bb7459-o_a.jpg', 'https://photos.zillowstatic.com/fp/430cfc9422632b0a1b40d9f93691e8e5-o_a.jpg', 'https://photos.zillowstatic.com/fp/9a11f572d55e5d951ce1a8c71b8cad52-o_a.jpg', 'https://photos.zillowstatic.com/fp/aaf0d74fdf7d7d90cda6194368b2afb6-o_a.jpg', 'https://photos.zillowstatic.com/fp/d2b96c7b1d770ac9062f19befd8ae14d-o_a.jpg', 'https://photos.zillowstatic.com/fp/57d5753396cbe26ffda408b01a725a1b-o_a.jpg', 'https://photos.zillowstatic.com/fp/7c296723d81046078e278488f03bdd0a-o_a.jpg', 'https://photos.zillowstatic.com/fp/2998cec13b4bd76e6735ee3b36a35d0a-o_a.jpg', 'https://photos.zillowstatic.com/fp/15099d5aceab94cb84ec3aea58a61f6f-o_a.jpg', 'https://photos.zillowstatic.com/fp/0b35c5869778375bb08947db6953d4f4-o_a.jpg', 'https://photos.zillowstatic.com/fp/e16250892f30e7f6365abc70e49f0094-o_a.jpg', 'https://photos.zillowstatic.com/fp/3dd59a2ff0262e82e858354bbfa021b0-o_a.jpg', 'https://photos.zillowstatic.com/fp/388cfbc6391d4dd470bee3a253b19167-o_a.jpg', 'https://photos.zillowstatic.com/fp/6ebe5d7d69c1a3f44fef11b58a32eb9c-o_a.jpg', 'https://photos.zillowstatic.com/fp/1d8edfa772e0ff22c7d0b1d52709bda1-o_a.jpg', 'https://photos.zillowstatic.com/fp/3423f1277cbd1f53e1f45f05749d9d16-o_a.jpg', 'https://photos.zillowstatic.com/fp/7fa3cafdff1f74075b3406f521124976-o_a.jpg', 'https://photos.zillowstatic.com/fp/35c5756b952b1445319a9d5d3e94d51a-o_a.jpg', 'https://photos.zillowstatic.com/fp/6c20c8d3243fdff8fc658162ca5c705f-o_a.jpg', 'https://photos.zillowstatic.com/fp/0fada90430aa9f0cde01218f87596d36-o_a.jpg', 'https://photos.zillowstatic.com/fp/85babeb8506dcdf41ba81155dd2ba01f-o_a.jpg', 'https://photos.zillowstatic.com/fp/d7478059854120efb5aaa6a602a7c93f-o_a.jpg', 'https://photos.zillowstatic.com/fp/674c630060b013a9a451a5d66edef5de-o_a.jpg', 'https://photos.zillowstatic.com/fp/7bf9bb9e6d605b1abbb35b6efc147d9a-o_a.jpg', 'https://photos.zillowstatic.com/fp/8e30dbd61f8529467cc75ee83b630990-o_a.jpg', 'https://photos.zillowstatic.com/fp/2b6a64d3a5c369f2e1e859763c83b455-o_a.jpg', 'https://photos.zillowstatic.com/fp/4322916152cb4538206e2b29651ce02b-o_a.jpg', 'https://photos.zillowstatic.com/fp/819179f109f2edcc2e0bc81db68c98b9-o_a.jpg', 'https://photos.zillowstatic.com/fp/eb06b7b82d8e35e39dc9f8ae473d7366-o_a.jpg', 'https://photos.zillowstatic.com/fp/cf6710a0b50240b29e241bce9595dd95-o_a.jpg', 'https://photos.zillowstatic.com/fp/3656be6094b2b8ef15fdb12aa77c1af7-o_a.jpg', 'https://photos.zillowstatic.com/fp/7ae31b12f9d91bd7c856acaee93ab4ff-o_a.jpg', 'https://photos.zillowstatic.com/fp/b0b326374bbf60a0d0c49ceade630080-o_a.jpg', 'https://photos.zillowstatic.com/fp/5751de6f5be80b45aa5d016272af0e8c-o_a.jpg', 'https://photos.zillowstatic.com/fp/cfd417b7b292da45a22aec9098c6e346-o_a.jpg', 'https://photos.zillowstatic.com/fp/5b1 ...
# 1

# %%
MSE= {}
for key,value in dfs_by_category.items():
    if(len(value)>20):
        df_check=value
        df_check=df_check.drop(columns=['description','homeInsights','image_captions','address.city','address.state'])
        scaler=StandardScaler()
        X=scaler.fit_transform(df_check)
        sse = []
        # Try different values of k (number of clusters)
        for k in range(2, 40):
            kmeans = KMeans(n_clusters=k,init='k-means++', random_state=42)
            kmeans.fit(X)
            sse.append(kmeans.inertia_) 
        
        MSE[key]=sse
# Out:
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
MSE
# Out:
# {'AL': [453.58711321160973,
#   345.2757543365967,
#   237.730539695036,
#   176.51377805608826,
#   142.67916166622257,
#   124.83786631153544,
#   103.51229365228484,
#   87.39194592007101,
#   77.81070590662983,
#   68.98895233801508,
#   62.63784927206358,
#   54.46212379726438,
#   49.030845411526904,
#   46.22140250480321,
#   41.79259465784033,
#   37.28434064426261,
#   34.92271289931316,
#   32.41717404073208,
#   29.312353878136438,
#   25.78159493858037,
#   24.44257805393633,
#   23.614483757680865,
#   21.304463185744368,
#   20.320198050872857,
#   18.623730522389888,
#   17.37081811552819,
#   16.669755022022862,
#   15.858871324157068,
#   14.287020703370148,
#   13.525178970108238,
#   13.017654520970742,
#   11.244026231305234,
#   11.020422577917975,
#   10.416872797351358,
#   9.421207094246874,
#   9.18006987604196,
#   8.513435307139856,
#   7.658367633140241],
#  'DC': [3706.1819710597865,
#   2917.6522225442086,
#   2459.0116697803064,
#   2093.145594862419,
#   1865.4579937772387,
#   1724.2147902401607,
#   1605.9885050256064,
#   1498.1971642891424,
#   1415.2248578390775,
#   1336.8507398055044,
#   1253.0502053687956,
#   1174.736499569212,
#   1132.1575286490875,
#   1088.127341859582,
#   1046.429110993897,
#   1004.0640030143147,
#   967.8247316808153,
#   929.666385317117,
#   908.3289638874121,
#   884.5352933839829,
#   839.3489075676038,
#   818.8433025055692,
#   796.2039007952387,
#   779.9116807876634,
#   752.001436606967,
#   749.1736834592965,
#   714.6639821685261,
#   696.22799677581,
#   674.6564692381613,
#   659.4122320682603,
#   648.5301530399547,
#   637.796128379146,
#   619.9307700559938,
#   618.1138683739282,
#   605.3916741600668,
#   582.6933628304821,
#   580.7013231128456,
#   569.3354040247029],
#  'IL': [3346.605600442795,
#   2737.248507253345,
#   2278.9022810656606,
#   2009.2140267952163,
#   1834.9672183722046,
#   1646.9881905494267,
#   1513.6036535930627,
#   1403.517375290162,
#   1325.5982626645887,
#   1234.9636988688735,
#   1172.4527126949317,
#   1104.8966557507445,
#   1046.0281651748473,
#   990.7799125111549,
#   939.6782444123396,
#   913.7926403266334,
#   860.1988221656959,
#   843.1706324813946,
#   820.6572479937204,
#   777.7916272058317,
#   772.6718756192056,
#   740.595542090526,
#   728.7704628205141,
#   698.6537194454907,
#   697.8590513957608,
#   660.7839040297514,
#   648.1877882649101,
#   634.5337961962892,
#   626.0820001228572,
#   617.2129503409084,
#   608.582856517406,
#   572.7241359819163,
#   577.7537243836268,
#   560.8111319091477,
#   554.8776153697243,
#   545.439728354035,
#   530.8477118294275,
#   528.1893288653315],
#  'NV': [3460.892616135166,
#   2742.6367255537098,
#   2219.37984852814,
#   1864.464029704676,
#   1650.3118197252934,
#   1448.5196886117337,
#   1319.0617523908331,
#   1209.5969344357004,
#   1125.1649119448132,
#   1049.4191288190639,
#   996.2329469710492,
#   923.5185800620267,
#   885.2450487483991,
#   850.1605661878809,
#   844.142579011763,
#   803.775567569759,
#   782.7862377522332,
#   738.2704332349214,
#   740.0014204940281,
#   712.0707655153765,
#   702.6277751763691,
#   670.6199676130877,
#   652.3397790767668,
#   640.493784475659,
#   630.1344634854098,
#   614.6245814627065,
#   598.0779787867108,
#   577.77089523991,
#   575.5833080723354,
#   558.579788176693,
#   554.2235528306389,
#   541.2029179262257,
#   521.8517649019153,
#   522.8579376716589,
#   511.34217468427534,
#   498.80325182340675,
#   488.2674344510822,
#   484.28310601251826],
#  'AZ': [3277.944768322417,
#   2560.2440467771357,
#   2175.797489705767,
#   1955.455218809625,
#   1750.9600395435266,
#   1602.7705184098004,
#   1477.2997884415315,
#   1330.71981796622,
#   1237.7575067673752,
#   1210.4239447386456,
#   1094.2064393218031,
#   1023.8256932180998,
#   981.8939473371879,
#   945.5394302689964,
#   906.649506790444,
#   875.2365757611095,
#   833.6223466152202,
#   802.2303763083921,
#   775.6482636869973,
#   749.3928355182661,
#   709.6319482148537,
#   698.4679174621845,
#   658.4934505278788,
#   642.1340741591324,
#   630.0411449242432,
#   602.9807178900307,
#   584.0664815065352,
#   583.8626832359256,
#   559.2902460001932,
#   550.0915332854958,
#   526.1913995369033,
#   514.2584087232623,
#   501.97003864845897,
#   481.72534285293057,
#   465.2999462046951,
#   463.697235767709,
#   443.28834401594975,
#   434.6655965679639],
#  'PA': [3552.707109266853,
#   2993.579978454631,
#   2515.495408898161,
#   2211.644833384261,
#   2033.241609171718,
#   1878.9645635422949,
#   1730.166549497461,
#   1575.4333313042662,
#   1475.9589765974188,
#   1389.6645168271166,
#   1294.06370308127,
#   1252.2495320584776,
#   1211.5707037596521,
#   1157.9492858807666,
#   1121.705061140059,
#   1073.3781339783573,
#   1055.5423290292138,
#   1012.7255089476441,
#   989.9023417116315,
#   948.9143882060274,
#   920.2159475777689,
#   906.5971782868139,
#   864.5860065437906,
#   852.3124345354325,
#   826.0692193288658,
#   806.8539353973404,
#   794.060949379304,
#   769.5379389265872,
#   757.5633643026017,
#   740.840909837305,
#   720.9422608884016,
#   705.6596035031748,
#   688.3085960100608,
#   677.4857245311719,
#   672.3626409601738,
#   647.9497153222117,
#   641.648988904154,
#   635.5533820043462],
#  'GA': [3265.975326952268,
#   2429.62753646863,
#   2017.641006347556,
#   1641.5022678225794,
#   1391.4112808979394,
#   1266.3674981930246,
#   1184.9369171238357,
#   1101.48577049996,
#   1007.0055620177154,
#   943.9367511556372,
#   886.6235187815896,
#   846.59003422653,
#   814.0227163373514,
#   771.1665639825283,
#   750.3126640357286,
#   715.9433622813974,
#   696.2169413891352,
#   681.6559991472027,
#   661.0133150614922,
#   625.6099679698785,
#   618.4404716413517,
#   590.7726816114182,
#   588.2762542187247,
#   569.7006042721182,
#   541.6951958403786,
#   546.752883344448,
#   532.3494156575747,
#   518.4409943465758,
#   508.80803404595633,
#   498.88018651838587,
#   491.5740192715898,
#   476.50482052227983,
#   469.0452828381467,
#   463.8250841834797,
#   447.44548730324414,
#   447.59115022485304,
#   435.3645067451165,
#   430.0638250371776],
#  'CA': [8221.586203476416,
#   6880.7275096336525,
#   5776.037601998973,
#   5100.3791584947485,
#   4513.823283860554,
#   3991.5509355121812,
#   3560.836279371395,
#   3100.479919910157,
#   2872.7300771294676,
#   2768.751435976936,
#   2569.4616877677495,
#   2332.7425669805843,
#   2298.6298256200225,
#   2129.1809274516195,
#   2006.4638925053678,
#   1915.670903987575,
#   1850.4141563948106,
#   1792.0989567237134,
#   1772.5094994558065,
#   1710.2914188489844,
#   1655.175996916475,
#   1603.8601647614448,
#   1559.5986947445872,
#   1529.0544517565627,
#   1502.229528304985,
#   1471.2449926429495,
#   1432.9053039604444,
#   1389.2780769250892,
#   1374.7880094177788,
#   1331.145884620261,
#   1302.409337217326,
#   1296.9770157732491,
#   1259.3561503333403,
#   1237.5838332549688,
#   1222.5434014148439,
#   1193.4895802001524,
#   1184.1366284333458,
#   1159.222221285352],
#  'TX': [4431.1369520192075,
#   3866.3560850059184,
#   3410.507639548257,
#   2922.2490129228718,
#   2511.4637791541745,
#   2210.633781420922,
#   1881.9320453245753,
#   1684.189007687614,
#   1569.4185395189554,
#   1449.9885624083352,
#   1379.6451820987254,
#   1279.1552074664037,
#   1233.297719370476,
#   1183.3342825578131,
#   1161.6489570273789,
#   1084.7556725143995,
#   1057.1652911127385,
#   1015.2039515677453,
#   1007.892889219375,
#   961.1079219772896,
#   931.5330195172535,
#   902.5102199174291,
#   880.7752094553525,
#   869.7057993110064,
#   832.0523944966916,
#   802.9997676792633,
#   775.8732213242336,
#   761.2326399643175,
#   732.0094338246067,
#   710.0767106692426,
#   685.7611982281309,
#   673.4055057986438,
#   661.8530028447357,
#   631.7029337149577,
#   624.5142223222447,
#   621.7204286643582,
#   597.7154664489879,
#   578.2479012313565],
#  'NY': [3900.3512903371584,
#   2945.532405080494,
#   2568.541272746712,
#   2207.8758746116832,
#   1880.042687245184,
#   1644.0098634766584,
#   1455.970221630309,
#   1313.0691584941062,
#   1206.9480965491562,
#   1149.7615815326487,
#   1093.875477035188,
#   996.9589612126306,
#   957.7617949693681,
#   909.1460670851103,
#   870.5007301212422,
#   843.5061380844544,
#   801.1868743490943,
#   779.8325654866868,
#   756.9334760496798,
#   732.9880010270904,
#   713.6546609479033,
#   699.28771207209,
#   660.16158399854,
#   664.1407566369322,
#   644.1428599244873,
#   615.0061604734018,
#   613.9323549048747,
#   581.6840076987506,
#   569.701262821306,
#   558.3344325017538,
#   551.4470708883705,
#   537.4353786928227,
#   512.1718262315323,
#   510.724972090474,
#   502.83299612730127,
#   485.38673361406165,
#   475.2519992122089,
#   471.1005978867891],
#  'FL': [3193.4571994528824,
#   2466.8634905958543,
#   1940.3969033212315,
#   1572.8325573099112,
#   1319.4102207195626,
#   1159.4781710751565,
#   1070.7839905505007,
#   966.5590664743258,
#   883.9887801558045,
#   839.0306308606798,
#   768.2537204809098,
#   739.8113417158709,
#   676.2710302851009,
#   640.5648280693742,
#   602.807534371533,
#   585.9890347715814,
#   567.7974110994938,
#   540.9879860825952,
#   528.9272280664768,
#   498.4820704405351,
#   473.97447604762624,
#   464.0648149858302,
#   453.98539941736914,
#   436.96297361054934,
#   423.0280415326778,
#   408.7971808122092,
#   398.1888281499105,
#   386.857303637627,
#   379.19629882895526,
#   365.39321536101306,
#   369.68845435821197,
#   350.57063957387845,
#   348.87828014457193,
#   342.6270024177673,
#   329.61488811137224,
#   321.49210920163074,
#   310.31568291964606,
#   316.4800700246763],
#  'MA': [2985.5805811438313,
#   2412.518163614334,
#   1938.8971292265765,
#   1547.6177537828132,
#   1269.7519963003833,
#   959.9043438718562,
#   813.4258884927286,
#   700.0537911813459,
#   577.7398795822005,
#   513.0459489655648,
#   448.8099305544203,
#   409.6487921592193,
#   387.52438938628876,
#   361.30992572692725,
#   344.17801391903356,
#   326.7985878122464,
#   306.00827792086784,
#   283.0451500351045,
#   271.9689037384833,
#   264.90267718453606,
#   249.20149062487576,
#   230.45041972610673,
#   226.7562942913522,
#   215.71821393102945,
#   208.9412571244421,
#   194.18700855289904,
#   191.16648288044016,
#   184.5721053999913,
#   175.94069777054358,
#   171.0931067623243,
#   163.99031529875828,
#   163.08388644382939,
#   156.44501624870696,
#   150.90691703817305,
#   146.91203654717765,
#   142.4228645043272,
#   140.09442681137813,
#   133.61355254449495],
#  'MI': [3325.8135718652243,
#   2721.594631239343,
#   2309.0691886142686,
#   1959.8931254290414,
#   1745.7051486180428,
#   1577.4718109902674,
#   1444.3501102565565,
#   1324.584371457957,
#   1210.5274081167966,
#   1148.295669210936,
#   1085.8844720110692,
#   1027.1643739764925,
#   969.9053732893519,
#   934.105412387582,
#   902.382955367698,
#   868.6450843946932,
#   843.2726211631734,
#   807.9809007896881,
#   784.8698867810357,
#   766.5802351209992,
#   743.8975866261529,
#   727.9030078760788,
#   709.772698584831,
#   682.3349983508684,
#   676.6007089461316,
#   661.7421258062841,
#   652.8151002350443,
#   626.8325701138222,
#   607.1237282632821,
#   595.7004888756824,
#   589.8885549366266,
#   569.7088554156815,
#   556.1506917898843,
#   539.9605479957894,
#   538.5569911986007,
#   524.340577485469,
#   510.07840459132603,
#   505.6181785653388]}

# %%
for key,value in MSE.items():
        
    plt.plot(range(2, 40), value, marker='o')
    plt.title(f'Elbow Method: {key}')
    plt.xlabel('Number of clusters')
    plt.ylabel('Sum of Squared Distances')
    plt.show()

# %%
kmeans=KMeans(n_clusters=20)
df_check=dfs_by_category['NY'].drop(columns=['description','homeInsights','image_captions','address.city','address.state'])

kmeans.fit(scaler.fit_transform(df_check))
kmeans.labels_
# Out:
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\kalya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# array([12, 12, 15,  0,  5,  5,  5,  7,  7, 18,  5, 19,  5,  5,  7,  5,  5,
#         5,  7,  0,  0,  0, 13, 16,  1, 15,  5,  5,  5,  7,  5,  5,  5, 13,
#        13,  5,  7, 19,  7,  7, 13,  0,  0,  7,  0,  0,  3,  3,  8, 13,  0,
#        14, 14,  9,  1, 10,  0, 11,  1,  0,  6,  3,  5,  3,  1, 15,  7, 15,
#         9, 18,  5, 13,  0, 15, 15,  0, 13,  7,  5,  0,  0, 15,  5,  7,  0,
#        13, 13, 13,  0, 13,  3, 13,  0,  3, 15,  9,  9,  9, 15,  3, 15,  9,
#         0, 16,  5, 18,  5, 13, 13, 13, 15,  5, 13,  1,  9,  9, 13,  2, 13,
#         5,  7,  5,  9,  7,  7, 16,  7,  7,  0, 15,  7,  5, 16, 16,  0, 15,
#         0, 13,  5,  2,  3,  7,  3, 16,  3,  8,  7,  5,  0,  0, 15,  3, 15,
#        15, 16,  7, 15,  5, 15,  3, 15,  1, 16, 13,  5,  5, 16,  7, 15,  5,
#         2,  2,  2,  5,  7, 15, 16, 11, 15, 16, 13, 15,  2,  5, 13,  5,  2,
#         0,  5, 16, 16, 12,  3,  0,  5,  5,  5,  0,  9,  5, 15, 13,  0,  5,
#         5,  5,  0, 15,  3, 13, 16,  9, 16,  5,  3,  5,  5, 15,  2,  3,  9,
#         5,  5,  5,  3,  7,  7,  2,  3,  0, 13,  5,  0, 15, 16,  6,  6,  5,
#         5, 15, 16, 15,  0,  5,  7,  0, 16,  7, 10,  1, 13,  0,  0, 16, 16,
#        11,  1, 11,  0,  5,  7,  0,  7, 15,  5,  5,  5, 16,  5,  0, 13, 16,
#        15, 13, 18, 11,  5,  0, 13,  7, 13,  5,  0,  9,  5,  0,  7,  0,  9,
#         3,  0,  0, 13,  5, 13,  9,  0,  5, 13, 15, 13, 15, 15,  5,  5,  5,
#         5,  7, 16,  5,  5,  5, 13, 11,  9, 16,  0, 15,  5, 15, 16,  5,  1,
#        13, 18, 13,  7, 18,  9,  5,  5, 15, 18,  2,  2,  2,  5,  7,  1,  1,
#         7,  0,  7,  0, 15,  5,  0,  7,  7,  1,  3,  9,  9, 11,  2,  2,  2,
#         2,  7,  1,  1,  5,  3,  7,  2, 15,  7,  7,  7,  7,  1,  7,  7,  7,
#         7, 16, 11,  1,  1,  0, 17, 15,  9, 13,  5, 13, 13,  1, 13, 16, 16,
#        13, 16, 11, 13,  0,  7, 16,  5,  7,  5, 16,  1, 13,  0,  3,  3, 16,
#         1,  5, 13,  5, 15,  3,  3,  5, 13, 15,  1, 11,  5,  1,  0, 16,  7,
#        16,  5,  3, 16, 15,  7,  7,  7, 11, 15,  7,  1, 16, 19,  0,  1,  0,
#         1,  7,  6, 13, 16, 13,  7,  3,  5,  8,  4, 16,  3,  5,  5, 14,  7,
#         7,  5, 10,  5, 11,  1,  8,  3, 16,  5, 13, 16,  7, 11,  7,  7,  0,
#         7,  3,  5,  1, 15,  7, 16,  7, 16, 16,  0,  0,  5, 12,  5, 12,  5,
#         1,  5, 15, 18, 15,  0, 16])

# %%
cluster_centers=scaler.inverse_transform(kmeans.cluster_centers_)
cols=df_check.columns
df_cluster_centers=pd.DataFrame(cluster_centers,columns=list(cols))
np.ceil(df_cluster_centers)
# Out:
#     bedrooms  bathrooms       price  homeType  livingArea  address.zipcode  \
# 0        1.0        2.0    873543.0       1.0       302.0          10038.0
# 1        4.0        5.0   7079036.0       1.0      2761.0          10032.0
# 2        2.0        2.0   1130765.0       1.0       227.0          10035.0
# 3        2.0        2.0   1012934.0       1.0       884.0          10031.0
# 4        0.0        1.0   1175000.0       1.0       729.0          11215.0
# 5        1.0        2.0    964214.0       1.0       368.0          10020.0
# 6        7.0        7.0   8611250.0       5.0      5369.0          10024.0
# 7        3.0        3.0   2809808.0       1.0      1646.0          10026.0
# 8        5.0        5.0   3555000.0       3.0      2525.0          10025.0
# 9        2.0        2.0    753800.0       1.0       454.0          10035.0
# 10       5.0        7.0  31500000.0       1.0      3999.0          10048.0
# 11       5.0        6.0  10687693.0       1.0      4993.0          10030.0
# 12       2.0        2.0   1126800.0       1.0       908.0          10281.0
# 13       3.0        3.0   2587490.0       1.0         1.0          10032.0
# 14       8.0        7.0   2398000.0       3.0      4027.0          10031.0
# 15       1.0        2.0   1000294.0       1.0       461.0          10019.0
# 16       3.0        3.0   2414330.0       1.0      1073.0          10021.0
# 17       2.0       12.0   3980000.0       1.0      1283.0          10023.0
# 18       1.0        2.0   1470625.0       0.0       318.0          10011.0
# 19       3.0        5.0   3981667.0       5.0      1244.0          10032.0
#
#     leisure_within_5km  shops_within_5km  schools_within_5km  \
# 0                 22.0             619.0               168.0
# 1                 22.0             606.0               169.0
# 2                 -0.0               0.0                 0.0
# 3                 32.0             410.0               208.0
# 4                  0.0               0.0                 0.0
# 5                 23.0             756.0               182.0
# 6                 20.0             513.0               177.0
# 7                 23.0             701.0               175.0
# 8                 30.0             516.0               184.0
# 9                 41.0             146.0               162.0
# 10                21.0             660.0               168.0
# 11                21.0             600.0               159.0
# 12                20.0             545.0               129.0
# 13                22.0             683.0               180.0
# 14                44.0             258.0               196.0
# 15                20.0             538.0               157.0
# 16                21.0             533.0               155.0
# 17                21.0             638.0               165.0
# 18                25.0             715.0               185.0
# 19                26.0             632.0               194.0
#
#     transit_within_2km
# 0                302.0
# 1                279.0
# 2                  1.0
# 3                312.0
# 4                  0.0
# 5                346.0
# 6                257.0
# 7                338.0
# 8                293.0
# 9                131.0
# 10               343.0
# 11               253.0
# 12               129.0
# 13               327.0
# 14               244.0
# 15               204.0
# 16               212.0
# 17               348.0
# 18               350.0
# 19               345.0
